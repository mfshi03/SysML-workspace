# %%
part def Truck specializes Vehicle {
  // Attributes
  attribute cargoCapacity : MassValue;
  attribute bedLength : LengthValue;
  attribute bedWidth : LengthValue;
  attribute hasLiftGate : Boolean;

  // Parts
  part cargoBed : CargoBed;
  part engine : Engine;
  part wheels : Wheel[4];

  // Ports
  port fuelPort : FuelPort;
  port cargoDoor : CargoDoorPort;

  // Actions
  action loadCargo(item cargo : Cargo) {
    // Action body specifying how cargo is loaded
  }
  action unloadCargo() {
    // Action body specifying how cargo is unloaded
  }
  action openCargoDoor() {
    // Action body specifying how the cargo door is opened
  }
  action closeCargoDoor() {
    // Action body specifying how the cargo door is closed
  }

  // States
  exhibit state truckStates {
    state parked;
    state driving;
    state loading;
    state unloading;
    // ... Transitions between states ...
  }

  // Requirements
  require constraint { cargoCapacity > 0[kg] };
  require constraint { bedLength > 0[m] };
  require constraint { bedWidth > 0[m] };
}
# Out:
# ERROR:no viable alternative at input '(' (6.sysml line : 18 column : 19)
# ERROR:no viable alternative at input ')' (6.sysml line : 18 column : 33)
# ERROR:no viable alternative at input '(' (6.sysml line : 21 column : 21)
# ERROR:no viable alternative at input '(' (6.sysml line : 24 column : 23)
# ERROR:no viable alternative at input '(' (6.sysml line : 27 column : 24)
# ERROR:missing EOF at 'require' (6.sysml line : 41 column : 3)

# %%
package TruckModel {

  // Part Definitions
  part def Engine {
    // Engine specific attributes, ports, actions, and states
  }

  part def Transmission {
    // Transmission specific attributes, ports, actions, and states
  }

  part def Drivetrain {
    // Drivetrain specific attributes, ports, actions, and states
  }

  part def Wheel {
    // Wheel specific attributes, ports, actions, and states
  }

  part def Suspension {
    // Suspension specific attributes, ports, actions, and states
  }

  part def Brakes {
    // Brakes specific attributes, ports, actions, and states
  }

  part def SteeringSystem {
    // Steering system specific attributes, ports, actions, and states
  }

  part def Frames {
    // Frame specific attributes, ports, actions, and states
  }

  part def Cab {
    // Cab specific attributes, ports, actions, and states
  }

  part def CargoArea {
    // Cargo area specific attributes, ports, actions, and states
  }

  // Part Usage
  part truck : Truck {

    // Composite Parts
    part engine : Engine;
    part transmission : Transmission;
    part drivetrain : Drivetrain;
    part frontWheels : Wheel [2];
    part rearWheels : Wheel [2];
    part suspension : Suspension;
    part brakes : Brakes;
    part steeringSystem : SteeringSystem;
    part frame : Frames;
    part cab : Cab;
    part cargoArea : CargoArea;

    // Connections
    connect engine.powerOutput to transmission.powerInput;
    connect transmission.torqueOutput to drivetrain.torqueInput;
    connect drivetrain.frontTorqueOutput to frontWheels.torqueInput;
    connect drivetrain.rearTorqueOutput to rearWheels.torqueInput;
    connect suspension.input to frame.output;
    connect brakes.input to wheels.brakeInput;
    connect steeringSystem.input to frontWheels.steeringInput;

  }

}
# Out:
# ERROR:no viable alternative at input 'frame' (1.sysml line : 56 column : 5)
# ERROR:no viable alternative at input 'frame' (1.sysml line : 65 column : 33)
# ERROR:no viable alternative at input 'output' (1.sysml line : 65 column : 39)

# %%
package TruckModel {

  // Part Definitions
  part def Engine {
    // Engine specific attributes, ports, actions, and states
    port powerOutput;
  }

  part def Transmission {
    // Transmission specific attributes, ports, actions, and states
    port powerInput;
    port torqueOutput;
  }

  part def Drivetrain {
    // Drivetrain specific attributes, ports, actions, and states
    port torqueInput;
    port frontTorqueOutput;
    port rearTorqueOutput;
  }

  part def Wheel {
    // Wheel specific attributes, ports, actions, and states
    port torqueInput;
    port brakeInput;
    port steeringInput;
  }

  part def Suspension {
    // Suspension specific attributes, ports, actions, and states
    port input;
  }

  part def Brakes {
    // Brakes specific attributes, ports, actions, and states
    port input;
  }

  part def SteeringSystem {
    // Steering system specific attributes, ports, actions, and states
    port input;
  }

  part def Frame {
    // Frame specific attributes, ports, actions, and states
    port output;
  }

  part def Cab {
    // Cab specific attributes, ports, actions, and states
  }

  part def CargoArea {
    // Cargo area specific attributes, ports, actions, and states
  }

  // Part Usage
  part truck {

    // Composite Parts
    part engine : Engine;
    part transmission : Transmission;
    part drivetrain : Drivetrain;
    part frontWheels : Wheel [2];
    part rearWheels : Wheel [2];
    part suspension : Suspension;
    part brakes : Brakes;
    part steeringSystem : SteeringSystem;
    //part frame : Frame;
    part cab : Cab;
    part cargoArea : CargoArea;

    // Connections
    connect engine.powerOutput to transmission.powerInput;
    connect transmission.torqueOutput to drivetrain.torqueInput;
    connect drivetrain.frontTorqueOutput to frontWheels.torqueInput;
    connect drivetrain.rearTorqueOutput to rearWheels.torqueInput;
    //connect suspension.input to frame.output;
    connect brakes.input to frontWheels.brakeInput;
    connect brakes.input to rearWheels.brakeInput;
    connect steeringSystem.input to frontWheels.steeringInput;

  }

}
# Out:
# Package TruckModel (76c22970-b540-4263-bed9-f2986027f393)

# %%
%viz --view=Tree TruckModel

# %%
package TruckModel {

  // Part Definitions
  part def Engine {
    // Engine specific attributes, ports, actions, and states
    port powerOutput;
  }

  part def Transmission {
    // Transmission specific attributes, ports, actions, and states
    port powerInput;
    port torqueOutput;
  }

  part def Drivetrain {
    // Drivetrain specific attributes, ports, actions, and states
    port torqueInput;
    port frontTorqueOutput;
    port rearTorqueOutput;
  }

  part def Wheel {
    // Wheel specific attributes, ports, actions, and states
    port torqueInput;
    port brakeInput;
    port steeringInput;
  }

  part def Suspension {
    // Suspension specific attributes, ports, actions, and states
    port input;
  }

  part def Brakes {
    // Brakes specific attributes, ports, actions, and states
    port input;
  }

  part def SteeringSystem {
    // Steering system specific attributes, ports, actions, and states
    port input;
  }

  part def Frame {
      // Cargo area specific attributes, ports, actions, and states
    port output;
  }

  part def Cab {
    // Cab specific attributes, ports, actions, and states
  }

  part def CargoArea {
    // Cargo area specific attributes, ports, actions, and states
  }

  // Part Usage
  part truck {

    // Composite Parts
    part engine : Engine;
    part transmission : Transmission;
    part drivetrain : Drivetrain;
    part frontWheels : Wheel [2];
    part rearWheels : Wheel [2];
    part suspension : Suspension;
    part brakes : Brakes;
    part steeringSystem : SteeringSystem;
    part frame_object : Frame;
    part cab : Cab;
    part cargoArea : CargoArea;

    // Connections
    connect engine.powerOutput to transmission.powerInput;
    connect transmission.torqueOutput to drivetrain.torqueInput;
    connect drivetrain.frontTorqueOutput to frontWheels.torqueInput;
    connect drivetrain.rearTorqueOutput to rearWheels.torqueInput;
    //connect suspension.input to frame_object.output;
    connect brakes.input to frontWheels.brakeInput;
    connect brakes.input to rearWheels.brakeInput;
    connect steeringSystem.input to frontWheels.steeringInput;

  }

}
# Out:
# Package TruckModel (54b835d2-5631-4c19-b427-c1aaf66288cf)

# %%
%viz --view=Tree TruckModel

# %%
package TruckModel {

  // Part Definitions
  part def Engine {
    port powerOutput;
  }

  part def Transmission {
    port powerInput;
    port torqueOutput;
  }

  part def Drivetrain {
    port torqueInput;
    port frontTorqueOutput;
    port rearTorqueOutput;
  }

  part def Wheel {
    port torqueInput;
    port brakeInput;
    port steeringInput;
  }

  part def Suspension {
    port input;
  }

  part def Brakes {
      port input;
  }

  part def SteeringSystem {
    port input;
  }

  part def Frame {
    port output;
    port input;
  }

  part def Cab {
    // No ports needed for Cab in this model
  }

  part def CargoArea {
    // No ports needed for CargoArea in this model
  }

  // Part Usage
  part truck {

    // Composite Parts
    part engine : Engine;
    part transmission : Transmission;
    part drivetrain : Drivetrain;
    part frontWheels : Wheel [2];
    part rearWheels : Wheel [2];
    part suspension : Suspension;
    part brakes : Brakes;
    part steeringSystem : SteeringSystem;
    part framev : Frame;
    part cab : Cab;
    part cargoArea : CargoArea;

    // Connections
    connect engine.powerOutput to transmission.powerInput;
    connect transmission.torqueOutput to drivetrain.torqueInput;
    connect drivetrain.frontTorqueOutput to frontWheels.torqueInput;
    connect drivetrain.rearTorqueOutput to rearWheels.torqueInput;
    connect suspension.input to framev.output;
    connect brakes.input to frontWheels.brakeInput;
    connect brakes.input to rearWheels.brakeInput;
    connect steeringSystem.input to frontWheels.steeringInput;

  }

}
# Out:
# Package TruckModel (bd4fb48d-dad8-4140-976e-45d8b0028a89)

# %%
%viz --view=Tree TruckModel
